# %% [markdown]
# #### 1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU

# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv', encoding='latin-1')

# %%
df.describe(include=['object'])
# Out:
#        Company Product  TypeName   ScreenResolution  \
# count     1303    1303      1303               1303
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu  \
# count                         1303  1303       1303                   1303
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %%
# Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU
# def spl_cpu(my_str: str):
#     return my_str.split()[0]

df['Cpu_Company'] = df['Cpu'].apply(lambda my_str: my_str.split()[0])
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company
# 0      1339.69       Intel
# 1       898.94       Intel
# 2       575.00       Intel
# 3      2537.45       Intel
# 4      1803.60       Intel

# %%
# Создать новый признак Memory_Amount, 
# который будет содержать только количество Gb памяти без указания типа носителя
def parse_mem(my_str: str):
    my_str = my_str.split()
    res = 0
    for i in my_str:
        if i.endswith('GB') and i[:-2].isdigit():
            res += int(i[:-2])
        elif i.endswith('TB') and i[:-2].isdigit():
            res += int(i[:-2]) * 1024
    return res
        

# list_mem = ['128GB SSD + 1TB HDD', '64GB Flash Storage', '256GB SSD']
# print(f'{parse_mem(list_mem[2])}')
df['Memory_Amount'] = df['Memory'].apply(parse_mem)
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company  Memory_Amount
# 0      1339.69       Intel            128
# 1       898.94       Intel            128
# 2       575.00       Intel            256
# 3      2537.45       Intel            512
# 4      1803.60       Intel            256

# %%
# Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD/SDD/др.)

def mem_type(my_str: str):
    res = []
    if 'HDD' in my_str:
        res.append('HDD')
    if 'SSD' in my_str:
        res.append('SSD')
    if not res:
        return 'other'
    return '/'.join(res)

# list_mem = ['128GB SSD + 1TB HDD', '64GB Flash Storage', '256GB SSD']
# print(f'{mem_type(list_mem[2])}')
df['Memory_Type'] = df['Memory'].apply(mem_type)
df.sample(15)
# Out:
#       laptop_ID  Company                                    Product  \
# 1256       1274     Asus                          Rog G752VT-GC073T
# 87           89       HP                                     250 G6
# 889         900   Lenovo                          IdeaPad 110-17ACL
# 648         656  Toshiba                          Portege Z30-C-16J
# 622         629     Dell                              Inspiron 5570
# 364         370   Lenovo                          IdeaPad 320-15ISK
# 1269       1287     Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 576         583  Toshiba                            Tecra X40-D-10H
# 163         167   Lenovo                         Legion Y520-15IKBN
# 1140       1156   Lenovo                                ThinkPad X1
# 923         937  Toshiba                            Tecra Z50-C-140
# 619         626     Acer       CB5-132T-C9KK (N3160/4GB/32GB/Chrome
# 737         745     Dell                              Inspiron 5379
# 793         802   Lenovo                             Yoga 510-15IKB
# 254         259     Acer                                   Aspire 5
#
#                 TypeName  Inches                 ScreenResolution  \
# 1256              Gaming    17.3      IPS Panel Full HD 1920x1080
# 87              Notebook    15.6                Full HD 1920x1080
# 889             Notebook    17.3                         1600x900
# 648             Notebook    13.3                Full HD 1920x1080
# 622             Notebook    15.6                Full HD 1920x1080
# 364             Notebook    15.6                         1366x768
# 1269            Notebook    15.6                         1366x768
# 576            Ultrabook    14.0  Full HD / Touchscreen 1920x1080
# 163               Gaming    15.6      IPS Panel Full HD 1920x1080
# 1140  2 in 1 Convertible    14.0  IPS Panel Touchscreen 2560x1440
# 923             Notebook    15.6      IPS Panel Full HD 1920x1080
# 619   2 in 1 Convertible    11.6   IPS Panel Touchscreen 1366x768
# 737   2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 793   2 in 1 Convertible    15.6  Full HD / Touchscreen 1920x1080
# 254             Notebook    17.3      IPS Panel Full HD 1920x1080
#
#                                        Cpu   Ram                Memory  \
# 1256           Intel Core i7 6700HQ 2.6GHz  16GB  128GB SSD +  1TB HDD
# 87              Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 889              AMD A4-Series 7210 2.2GHz   4GB             500GB HDD
# 648             Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 622             Intel Core i5 8250U 1.6GHz   4GB               1TB HDD
# 364               Intel Core i3 6006U 2GHz   8GB             256GB SSD
# 1269            Intel Core i7 6500U 2.5GHz   4GB             500GB HDD
# 576             Intel Core i7 7500U 2.7GHz  16GB             512GB SSD
# 163            Intel Core i7 7700HQ 2.8GHz  16GB             256GB SSD
# 1140            Intel Core i7 6600U 2.6GHz  16GB             512GB SSD
# 923             Intel Core i7 6600U 2.6GHz  16GB             256GB SSD
# 619   Intel Celeron Quad Core N3160 1.6GHz   4GB    32GB Flash Storage
# 737             Intel Core i5 8250U 1.6GHz   8GB               1TB HDD
# 793             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 254             Intel Core i3 7130U 2.7GHz   4GB             256GB SSD
#
#                              Gpu       OpSys  Weight  Price_euros Cpu_Company  \
# 1256     Nvidia GeForce GTX 970M  Windows 10   4.0kg      1900.00       Intel
# 87         Intel HD Graphics 620  Windows 10  1.96kg       598.99       Intel
# 889                AMD Radeon R3  Windows 10   2.8kg       379.00         AMD
# 648        Intel HD Graphics 520  Windows 10   1.2kg      1213.00       Intel
# 622               AMD Radeon 530  Windows 10   2.2kg       776.00       Intel
# 364        Nvidia GeForce 920MX        No OS   2.2kg       499.00       Intel
# 1269         Nvidia GeForce 920M  Windows 10   2.2kg       720.32       Intel
# 576        Intel HD Graphics 620  Windows 10  1.24kg      1865.00       Intel
# 163   Nvidia GeForce GTX 1050 Ti  Windows 10   2.5kg      1079.00       Intel
# 1140       Intel HD Graphics 520  Windows 10   2.8kg      2440.00       Intel
# 923          Nvidia GeForce 930M  Windows 10   2.4kg      1975.00       Intel
# 619        Intel HD Graphics 400   Chrome OS  1.25kg       379.00       Intel
# 737       Intel UHD Graphics 620  Windows 10  1.55kg       659.00       Intel
# 793           AMD Radeon R7 M460  Windows 10  2.08kg       959.00       Intel
# 254         Nvidia GeForce MX130  Windows 10     3kg       702.00       Intel
#
#       Memory_Amount Memory_Type
# 1256           1152     HDD/SSD
# 87              256         SSD
# 889             500         HDD
# 648             256         SSD
# 622            1024         HDD
# 364             256         SSD
# 1269            500         HDD
# 576             512         SSD
# 163             256         SSD
# 1140            512         SSD
# 923             256         SSD
# 619              32       other
# 737            1024         HDD
# 793             256         SSD
# 254             256         SSD

# %% [markdown]
# Удалите признаки Memory и ScreenResolution

# %%
# Удалите признаки Memory и ScreenResolution
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)
df.sample(15)
# Out:
#       laptop_ID  Company                                    Product  \
# 69           71     Asus  FX753VE-GC093 (i7-7700HQ/12GB/1TB/GeForce
# 802         811     Dell                                     XPS 13
# 863         874   Lenovo                         Legion Y520-15IKBN
# 1157       1175   Lenovo                             ThinkPad T460s
# 1011       1025       HP                              EliteBook 820
# 1177       1195   Lenovo                         IdeaPad Y700-15ISK
# 479         486  Toshiba                          Portege X30-D-10J
# 88           90     Asus         FX503VM-E4007T (i7-7700HQ/16GB/1TB
# 1226       1244     Dell                                     XPS 13
# 89           91     Dell                                     XPS 13
# 486         493     Dell                             Precision 3520
# 6             7    Apple                                MacBook Pro
# 962         976     Acer                        Aspire F5-573G-510L
# 1210       1228    Apple                                MacBook 12"
# 112         115   Lenovo                              ThinkPad Yoga
#
#                 TypeName  Inches                          Cpu   Ram  \
# 69                Gaming    17.3  Intel Core i7 7700HQ 2.8GHz  12GB
# 802            Ultrabook    13.3   Intel Core i5 7200U 2.5GHz   8GB
# 863               Gaming    15.6  Intel Core i5 7300HQ 2.5GHz   8GB
# 1157           Ultrabook    14.0   Intel Core i7 6600U 2.6GHz  12GB
# 1011           Ultrabook    12.5   Intel Core i5 7200U 2.5GHz   4GB
# 1177              Gaming    15.6  Intel Core i7 6700HQ 2.6GHz  16GB
# 479             Notebook    13.3   Intel Core i5 7200U 2.5GHz   8GB
# 88                Gaming    15.6  Intel Core i7 7700HQ 2.8GHz  16GB
# 1226           Ultrabook    13.3   Intel Core i7 7500U 2.7GHz   8GB
# 89             Ultrabook    13.3   Intel Core i7 8550U 1.8GHz   8GB
# 486          Workstation    15.6  Intel Core i7 6820HQ 2.7GHz  16GB
# 6              Ultrabook    15.4         Intel Core i7 2.2GHz  16GB
# 962             Notebook    15.6   Intel Core i5 7200U 2.5GHz  12GB
# 1210           Ultrabook    12.0          Intel Core M 1.2GHz   8GB
# 112   2 in 1 Convertible    13.3   Intel Core i5 7200U 2.5GHz   8GB
#
#                              Gpu       OpSys   Weight  Price_euros  \
# 69    Nvidia GeForce GTX 1050 Ti       Linux      3kg       949.00
# 802        Intel HD Graphics 620  Windows 10   1.29kg      1499.00
# 863      Nvidia GeForce GTX 1050       No OS    2.5kg      1017.00
# 1157       Intel HD Graphics 520   Windows 7    1.4kg      2299.00
# 1011       Intel HD Graphics 620  Windows 10   1.26kg      1539.00
# 1177      Nvidia GeForce GTX 960  Windows 10   3.31kg      1305.00
# 479        Intel HD Graphics 620  Windows 10   1.05kg      1672.00
# 88       Nvidia GeForce GTX 1060  Windows 10    2.2kg      1449.00
# 1226       Intel HD Graphics 620  Windows 10   1.29kg      1477.00
# 89        Intel UHD Graphics 620  Windows 10   1.21kg      1649.00
# 486           Nvidia Quadro M620  Windows 10   2.17kg      2338.00
# 6        Intel Iris Pro Graphics    Mac OS X   2.04kg      2139.97
# 962      Nvidia GeForce GTX 950M  Windows 10    2.4kg      1009.00
# 1210       Intel HD Graphics 515    Mac OS X  0.920kg      1279.00
# 112        Intel HD Graphics 620  Windows 10   1.37kg      1399.00
#
#      Cpu_Company  Memory_Amount Memory_Type
# 69         Intel           1024         HDD
# 802        Intel            256         SSD
# 863        Intel           1024         HDD
# 1157       Intel            512         SSD
# 1011       Intel            500         HDD
# 1177       Intel            512         SSD
# 479        Intel            256         SSD
# 88         Intel           1152     HDD/SSD
# 1226       Intel            256         SSD
# 89         Intel            256         SSD
# 486        Intel            512         SSD
# 6          Intel            256       other
# 962        Intel           1152     HDD/SSD
# 1210       Intel            512       other
# 112        Intel            256         SSD

# %%
# 2.1 Создайте признак SSD, который изначально равен 0
# 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD


# df['SSD'] = 0
df['SSD'] = df['Memory_Type'].apply(lambda my_str: 1 if 'SSD' in my_str else 0) 
# df['SSD'] = 0
# df.loc['SSD' in df['Memory_Type'], 'SSD'] = 1
df.sample(5)
# Out:
#       laptop_ID Company                                Product     TypeName  \
# 971         985    Dell                         Latitude E7470    Ultrabook
# 703         711  Lenovo  V310-15IKB (i5-7200U/4GB/1TB/FHD/W10)     Notebook
# 1192       1210      HP                                 250 G6     Notebook
# 297         302    Dell                         Precision 7720  Workstation
# 180         184    Dell                          Inspiron 5570     Notebook
#
#       Inches                          Cpu   Ram                    Gpu  \
# 971     14.0   Intel Core i7 6600U 2.6GHz   8GB  Intel HD Graphics 520
# 703     15.6   Intel Core i5 7200U 2.5GHz   4GB  Intel HD Graphics 620
# 1192    15.6   Intel Core i5 7200U 2.5GHz   4GB  Intel HD Graphics 620
# 297     17.3  Intel Core i7 7820HQ 2.9GHz  16GB    Nvidia Quadro M1200
# 180     15.6   Intel Core i7 8550U 1.8GHz  16GB         AMD Radeon 530
#
#            OpSys  Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  \
# 971   Windows 10   1.5kg      1962.98       Intel            256         SSD
# 703   Windows 10   2.1kg       621.45       Intel           2048         HDD
# 1192  Windows 10  1.86kg       485.00       Intel            500         HDD
# 297   Windows 10  3.42kg      2884.86       Intel            256         SSD
# 180        Linux  2.02kg      1049.00       Intel           2304     HDD/SSD
#
#       SSD
# 971     1
# 703     0
# 1192    0
# 297     1
# 180     1

# %%
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный
df['Weight'] = df['Weight'].str.replace('kg', '')
df['Weight'].astype('float')
df.sample(10)
# Out:
#       laptop_ID Company                              Product  \
# 1243       1261    Dell                        Inspiron 7779
# 246         251      HP    15-bs015dx (i5-7200U/8GB/1TB/W10)
# 965         979    Dell                        Inspiron 3567
# 150         153    Dell                        Inspiron 5577
# 370         376    Asus                         ZenBook Flip
# 476         483    Dell                      Precision M5520
# 1055       1069      HP                          ProBook 650
# 1210       1228   Apple                          MacBook 12"
# 477         484  Lenovo                        Thinkpad T470
# 171         175      HP  17-bs001nv (i5-7200U/6GB/2TB/Radeon
#
#                 TypeName  Inches                          Cpu   Ram  \
# 1243  2 in 1 Convertible    17.3   Intel Core i7 7500U 2.7GHz  16GB
# 246             Notebook    15.6   Intel Core i5 7200U 2.5GHz   8GB
# 965             Notebook    15.6   Intel Core i3 6006U 2.0GHz   4GB
# 150               Gaming    15.6  Intel Core i7 7700HQ 2.8GHz  16GB
# 370   2 in 1 Convertible    15.6   Intel Core i7 7500U 2.7GHz  12GB
# 476          Workstation    15.6  Intel Core i7 7700HQ 2.8GHz   8GB
# 1055            Notebook    15.6   Intel Core i3 6100U 2.3GHz   4GB
# 1210           Ultrabook    12.0          Intel Core M 1.2GHz   8GB
# 477             Notebook    14.0   Intel Core i5 7200U 2.5GHz   8GB
# 171             Notebook    17.3   Intel Core i5 7200U 2.5GHz   6GB
#
#                           Gpu       OpSys Weight  Price_euros Cpu_Company  \
# 1243     Nvidia GeForce 940MX  Windows 10   2.77      1799.00       Intel
# 246     Intel HD Graphics 620  Windows 10   2.04       559.00       Intel
# 965        AMD Radeon R5 M430       Linux   2.25       465.62       Intel
# 150   Nvidia GeForce GTX 1050  Windows 10   2.56      1249.26       Intel
# 370   Nvidia GeForce GT 940MX  Windows 10   2.26      1099.00       Intel
# 476       Nvidia Quadro M1200  Windows 10   1.78      2408.00       Intel
# 1055    Intel HD Graphics 520  Windows 10   2.31       705.15       Intel
# 1210    Intel HD Graphics 515    Mac OS X  0.920      1279.00       Intel
# 477     Intel HD Graphics 620  Windows 10    1.7      1364.00       Intel
# 171            AMD Radeon 520  Windows 10   2.71       699.00       Intel
#
#       Memory_Amount Memory_Type  SSD
# 1243            512         SSD    1
# 246            1024         HDD    0
# 965            1024         HDD    0
# 150             512         SSD    1
# 370            2560     HDD/SSD    1
# 476             256         SSD    1
# 1055            500         HDD    0
# 1210            512       other    0
# 477             180         SSD    1
# 171            2048         HDD    0

# %% [markdown]
# ### Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
#     'client_id': [45, 32, 67, 33, 43],
#     'laptop_id': [506, 398, 710, 120, 1999]
# })
# ##### laptop_id - это индексы датафрейма с ноутбуками
# ### 3.1 Присоедините к таблице clients данные по ноутбукам через метод join
# ### 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
clients.head()
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
clients_1 = clients.set_index('laptop_id')

# %%
laptop_1 = df.set_index('laptop_ID')

# %%
clients_1.head()
laptop_1.head()
# Out:
#           Company      Product   TypeName  Inches                         Cpu  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz
# 2           Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 3              HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz
# 4           Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz
# 5           Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz
#
#             Ram                           Gpu  OpSys  Weight  Price_euros  \
# laptop_ID
# 1           8GB  Intel Iris Plus Graphics 640  macOS    1.37      1339.69
# 2           8GB        Intel HD Graphics 6000  macOS    1.34       898.94
# 3           8GB         Intel HD Graphics 620  No OS    1.86       575.00
# 4          16GB            AMD Radeon Pro 455  macOS    1.83      2537.45
# 5           8GB  Intel Iris Plus Graphics 650  macOS    1.37      1803.60
#
#           Cpu_Company  SSD
# laptop_ID
# 1               Intel    0
# 2               Intel    0
# 3               Intel    0
# 4               Intel    0
# 5               Intel    0

# %%
clients_1.join(laptop_1, how='inner')
# Out:
#      client_id Company            Product  TypeName  Inches  \
# 506         45  Lenovo      ThinkPad L570  Notebook    15.6
# 710         67  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 120         33    Dell      Inspiron 7570  Notebook    15.6
#
#                              Cpu  Ram                    Gpu       OpSys  \
# 506   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  Windows 10
# 710  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7  Windows 10
# 120   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX  Windows 10
#
#     Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 506    2.3       911.00       Intel            256         SSD    1
# 710    2.2       429.00         AMD           1024         HDD    0
# 120   2.16      1130.33       Intel           1280     HDD/SSD    1

# %%
clients.merge(df, left_on='laptop_id', right_on='laptop_ID')
# Out:
#    client_id  laptop_id  laptop_ID Company            Product  TypeName  \
# 0         45        506        506  Lenovo      ThinkPad L570  Notebook
# 1         67        710        710  Lenovo  IdeaPad 320-15ABR  Notebook
# 2         33        120        120    Dell      Inspiron 7570  Notebook
#
#    Inches                          Cpu  Ram                    Gpu  \
# 0    15.6   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620
# 1    15.6  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 2    15.6   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
#
#         OpSys Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 0  Windows 10    2.3       911.00       Intel            256         SSD    1
# 1  Windows 10    2.2       429.00         AMD           1024         HDD    0
# 2  Windows 10   2.16      1130.33       Intel           1280     HDD/SSD    1

# %%
## 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя Отсортируйте от меньшей стоимости к большей¶
df.groupby('Company').agg({'Price_euros': 'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %%
## 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

df.groupby('Cpu_Company').agg({'Price_euros': ['mean', 'min', 'max']}).sort_values(('Price_euros', 'mean'))
# Out:
#              Price_euros
#                     mean    min     max
# Cpu_Company
# AMD           560.638871  199.0  2199.0
# Samsung       659.000000  659.0   659.0
# Intel        1152.214145  174.0  6099.0

# %%
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ
df.pivot_table(index='Cpu_Company', columns='Ram', aggfunc='count', values = 'Product')
# Out:
# Ram          12GB   16GB  24GB   2GB  32GB    4GB  64GB   6GB    8GB
# Cpu_Company
# AMD           2.0    3.0   NaN   1.0   NaN   31.0   NaN  13.0   12.0
# Intel        23.0  197.0   3.0  21.0  17.0  343.0   1.0  28.0  607.0
# Samsung       NaN    NaN   NaN   NaN   NaN    1.0   NaN   NaN    NaN

# %%
# 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти


df.pivot_table(index='OpSys', columns='Memory_Amount', aggfunc='mean', values = 'Price_euros', fill_value=0)
# Out:
# Memory_Amount      0     8       16          32          64           128   \
# OpSys
# Android          0.0000     0    0.00    0.000000  434.000000     0.000000
# Chrome OS        0.0000     0  305.38  412.454545  774.333333  1275.000000
# Linux            0.0000     0    0.00    0.000000    0.000000   490.500000
# Mac OS X         0.0000     0    0.00    0.000000    0.000000  1099.000000
# No OS            0.0000     0    0.00    0.000000    0.000000   362.024000
# Windows 10     755.5575  2249    0.00  270.001471  333.795556   673.385692
# Windows 10 S     0.0000     0    0.00    0.000000  308.995000  1039.000000
# Windows 7      860.0000     0    0.00    0.000000    0.000000  1320.323333
# macOS            0.0000     0    0.00    0.000000    0.000000  1119.315000
#
# Memory_Amount    180   240          256         500   ...     768   \
# OpSys                                                 ...
# Android           0.0     0     0.000000    0.000000  ...     0.00
# Chrome OS         0.0     0  1559.000000    0.000000  ...     0.00
# Linux             0.0     0   795.814000  389.056364  ...     0.00
# Mac OS X          0.0     0  1311.994000    0.000000  ...     0.00
# No OS             0.0     0   754.834615  404.675385  ...     0.00
# Windows 10     1073.5  3100  1218.868329  664.717647  ...  1607.96
# Windows 10 S      0.0     0  1668.950000    0.000000  ...     0.00
# Windows 7      1199.0     0  1846.466800  924.048333  ...     0.00
# macOS             0.0     0  1600.370000    0.000000  ...     0.00
#
# Memory_Amount        1024  1088         1152        1280         1536  \
# OpSys
# Android           0.00000     0     0.000000     0.00000     0.000000
# Chrome OS         0.00000     0     0.000000     0.00000     0.000000
# Linux           581.40129     0   994.000000     0.00000     0.000000
# Mac OS X          0.00000     0     0.000000     0.00000     0.000000
# No OS           540.53960     0   895.666667  1149.00000     0.000000
# Windows 10      886.22663  1993  1285.464494  1865.97375  2500.447143
# Windows 10 S      0.00000     0     0.000000     0.00000     0.000000
# Windows 7      2899.00000     0     0.000000     0.00000     0.000000
# macOS             0.00000     0     0.000000     0.00000     0.000000
#
# Memory_Amount         2048    2176         2304  2560
# OpSys
# Android           0.000000    0.00     0.000000     0
# Chrome OS         0.000000    0.00     0.000000     0
# Linux             0.000000    0.00  1049.000000     0
# Mac OS X          0.000000    0.00     0.000000     0
# No OS           594.000000    0.00     0.000000     0
# Windows 10     1058.201333  977.95  1590.015556  1849
# Windows 10 S      0.000000    0.00     0.000000     0
# Windows 7         0.000000    0.00     0.000000     0
# macOS             0.000000    0.00     0.000000     0
#
# [9 rows x 23 columns]

# %%
# 5.1 Ноутбуков каких компаний и с каким процессором больше?

tmp_df = pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])

# %%
tmp_df.max()
# Out:
# Cpu_Company
# AMD         25
# Intel      297
# Samsung      1
# dtype: int64

# %%
# 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?
pd.crosstab(index=df['Memory_Amount'], columns=df['Memory_Type']).max()
# Out:
# Memory_Type
# HDD        223
# HDD/SSD     94
# SSD        413
# other       38
# dtype: int64

# %%
tmp_df1.max()
